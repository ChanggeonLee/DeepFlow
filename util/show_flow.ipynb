# %%
import matplotlib.pyplot as plt
import os
from os.path import isfile
import h5py
import numpy as np

# %%
path="/home/changgeonlee/mechsys/tflbm/data/fluid_flow_128x128/sample_5/"
shape = [128, 384]
class_names = os.listdir(path)
class_names.sort()
for idx, classname in enumerate(class_names):    
    h5_path = path+classname
    fname, ext = os.path.splitext(h5_path)
    if(ext == ".h5"):
        dataH5 = h5py.File(h5_path)

        key_list = dataH5.keys()
        flow = np.array(dataH5['Velocity_0'][:])
        flow = flow.reshape([shape[0], shape[1], 3])[0:shape[0],0:shape[1],0:2]

        boundary = np.array(dataH5['Gamma'][:])
        boundary = boundary.reshape([shape[0], shape[1], 1])[0:shape[0],0:shape[1],:]

        sflow_plot = np.concatenate([flow], axis=1)
        boundary_concat = np.concatenate(3*[boundary], axis=2)
        sflow_plot = np.sqrt(np.square(sflow_plot[:,:,0])) - .05 *boundary_concat[:,:,0]

        plt.imshow(sflow_plot)
        plt.colorbar()
        plt.show() 
    else:
        print("v="+classname)
# Out:
# v=0.10
# /home/changgeonlee/.pyenv/versions/3.7.1/envs/sound/lib/python3.7/site-packages/ipykernel_launcher.py:9: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#   if __name__ == '__main__':
# v=fluid_flow_0000.xmf
# v=fluid_flow_0001.xmf
# v=fluid_flow_0002.xmf
# v=fluid_flow_0003.xmf
# v=fluid_flow_0004.xmf
# v=fluid_flow_0005.xmf
# v=fluid_flow_0006.xmf
# v=fluid_flow_0007.xmf
# v=fluid_flow_0008.xmf
# v=fluid_flow_0009.xmf
# v=fluid_flow_0010.xmf
# v=fluid_flow_0011.xmf
# v=fluid_flow_0012.xmf
# v=fluid_flow_0013.xmf
# v=fluid_flow_0014.xmf
# v=fluid_flow_0015.xmf
# v=fluid_flow_0016.xmf
# v=fluid_flow_0017.xmf
# v=fluid_flow_0018.xmf
# v=fluid_flow_0019.xmf
# v=fluid_flow_0020.xmf
# v=fluid_flow_0021.xmf
# v=fluid_flow_0022.xmf
# v=fluid_flow_0023.xmf
# v=fluid_flow_0024.xmf
# v=fluid_flow_0025.xmf
# v=fluid_flow_0026.xmf
# v=fluid_flow_0027.xmf
# v=fluid_flow_0028.xmf
# v=fluid_flow_0029.xmf
# v=fluid_flow_0030.xmf
# v=fluid_flow_0031.xmf
# v=fluid_flow_0032.xmf
# v=fluid_flow_0033.xmf
# v=fluid_flow_0034.xmf
# v=fluid_flow_0035.xmf
# v=fluid_flow_0036.xmf
# v=fluid_flow_0037.xmf
# v=fluid_flow_0038.xmf
# v=fluid_flow_0039.xmf
# v=fluid_flow_0040.xmf
# v=fluid_flow_0041.xmf
# v=fluid_flow_0042.xmf
# v=fluid_flow_0043.xmf
# v=fluid_flow_0044.xmf
# v=fluid_flow_0045.xmf
# v=fluid_flow_0046.xmf
# v=fluid_flow_0047.xmf
# v=fluid_flow_0048.xmf
# v=fluid_flow_0049.xmf
# v=fluid_flow_0050.xmf
# v=fluid_flow_0051.xmf
# v=fluid_flow_0052.xmf
# v=fluid_flow_0053.xmf
# v=fluid_flow_0054.xmf
# v=fluid_flow_0055.xmf
# v=fluid_flow_0056.xmf
# v=fluid_flow_0057.xmf
# v=fluid_flow_0058.xmf
# v=fluid_flow_0059.xmf
# v=fluid_flow_0060.xmf
# v=fluid_flow_0061.xmf
# v=fluid_flow_0062.xmf
# v=fluid_flow_0063.xmf
# v=fluid_flow_0064.xmf
# v=fluid_flow_0065.xmf
# v=fluid_flow_0066.xmf
# v=fluid_flow_0067.xmf
# v=fluid_flow_0068.xmf
# v=fluid_flow_0069.xmf
# v=fluid_flow_0070.xmf
# v=fluid_flow_0071.xmf
# v=fluid_flow_0072.xmf
# v=fluid_flow_0073.xmf
# v=fluid_flow_0074.xmf
# v=fluid_flow_0075.xmf
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~/.pyenv/versions/3.7.1/envs/sound/lib/python3.7/site-packages/h5py/_hl/files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     198         try:
# --> 199             fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#     200         except IOError:
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5f.pyx in h5py.h5f.open()
#
# OSError: Unable to open file (unable to lock file, errno = 11, error message = 'Resource temporarily unavailable')
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# ~/.pyenv/versions/3.7.1/envs/sound/lib/python3.7/site-packages/h5py/_hl/files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     201             try:
# --> 202                 fid = h5f.open(name, h5f.ACC_RDONLY, fapl=fapl)
#     203             except IOError:
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5f.pyx in h5py.h5f.open()
#
# OSError: Unable to open file (unable to lock file, errno = 11, error message = 'Resource temporarily unavailable')
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# <ipython-input-4-6be30c43d9b5> in <module>
#       7     fname, ext = os.path.splitext(h5_path)
#       8     if(ext == ".h5"):
# ----> 9         dataH5 = h5py.File(h5_path)
#      10
#      11         key_list = dataH5.keys()
#
# ~/.pyenv/versions/3.7.1/envs/sound/lib/python3.7/site-packages/h5py/_hl/files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, **kwds)
#     406                 fid = make_fid(name, mode, userblock_size,
#     407                                fapl, fcpl=make_fcpl(track_order=track_order),
# --> 408                                swmr=swmr)
#     409
#     410             if isinstance(libver, tuple):
#
# ~/.pyenv/versions/3.7.1/envs/sound/lib/python3.7/site-packages/h5py/_hl/files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     202                 fid = h5f.open(name, h5f.ACC_RDONLY, fapl=fapl)
#     203             except IOError:
# --> 204                 fid = h5f.create(name, h5f.ACC_EXCL, fapl=fapl, fcpl=fcpl)
#     205     else:
#     206         raise ValueError("Invalid mode; must be one of r, r+, w, w-, x, a")
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5f.pyx in h5py.h5f.create()
#
# OSError: Unable to create file (unable to open file: name = '/home/changgeonlee/mechsys/tflbm/data/fluid_flow_128x128/sample_5/fluid_flow_0076.h5', errno = 17, error message = 'File exists', flags = 15, o_flags = c2)
